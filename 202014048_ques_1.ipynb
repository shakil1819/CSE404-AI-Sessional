# %% [markdown]
# <a href="https://colab.research.google.com/github/shakil1819/CSE404-AI-Sessional/blob/main/202014048_ques_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/CSE404- AI-Sessional/Evaluation-sec-B/heart_data.csv")

# %%
df
# Out:
#      chance_of _attack  age  sex  cp  trtbps  chol  fbs  restecg  thalachh  \
# 0                    1   63    1   3     145   233    1        0       150
# 1                    1   37    1   2     130   250    0        1       187
# 2                    1   41    0   1     130   204    0        0       172
# 3                    1   56    1   1     120   236    0        1       178
# 4                    1   57    0   0     120   354    0        1       163
# ..                 ...  ...  ...  ..     ...   ...  ...      ...       ...
# 298                  0   57    0   0     140   241    0        1       123
# 299                  0   45    1   3     110   264    0        1       132
# 300                  0   68    1   0     144   193    1        1       141
# 301                  0   57    1   0     130   131    0        1       115
# 302                  0   57    0   1     130   236    0        0       174
#
#      exng  oldpeak  slp  caa  thall
# ...

# %%
df.isnull().sum()
# Out:
# chance_of _attack    0
# age                  0
# sex                  0
# cp                   0
# trtbps               0
# chol                 0
# fbs                  0
# restecg              0
# thalachh             0
# exng                 0
# oldpeak              0
# slp                  0
# caa                  0
# thall                0
# dtype: int64

# %%
X=df.drop(columns=['chance_of _attack'])
X
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall
# 0      0      1
# 1      0      2
# ...

# %%
y=df['chance_of _attack']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: chance_of _attack, Length: 303, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.1)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,prediction)
score
# Out:
# 0.8709677419354839

# %%
from sklearn.linear_model import LogisticRegression
lg= LogisticRegression()
lg.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=lg.predict(X_test)
