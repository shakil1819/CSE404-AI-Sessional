# %% [markdown]
# <a href="https://colab.research.google.com/github/shakil1819/CSE404-AI-Sessional/blob/main/evaluation_secA_prob1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/CSE404- AI-Sessional/Evaluation-Sec-A/Body_Perfomance _Data.csv")

# %%
df
# Out:
#      age  gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0     25       1      165.0       55.8        15.7         77       126
# 1     31       1      179.6       78.0        20.1         92       152
# 2     32       1      174.5       71.1        18.4         76       147
# 3     28       1      173.8       67.7        17.1         70       127
# 4     36       2      165.4       55.4        22.0         64       119
# ..   ...     ...        ...        ...         ...        ...       ...
# 414   42       1      172.2       70.9        20.5         81       142
# 415   24       1      172.0       70.6        14.7         62       112
# 416   33       1      186.8      117.5        28.3         78       133
# 417   34       1      170.6       71.7         9.7         69       115
# 418   24       2      168.2       54.0        15.9         66       102
#
#      gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
df.isnull().sum()
# Out:
# age                        0
# gender                     0
# height_cm                  0
# weight_kg                  0
# body fat_%                 0
# diastolic                  0
# systolic                   0
# gripForce                  0
# sit and bend forward_cm    0
# sit-ups counts             0
# broad jump_cm              0
# class                      0
# dtype: int64

# %%
X=df.drop(columns=['class'])
X
# Out:
#      age  gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0     25       1      165.0       55.8        15.7         77       126
# 1     31       1      179.6       78.0        20.1         92       152
# 2     32       1      174.5       71.1        18.4         76       147
# 3     28       1      173.8       67.7        17.1         70       127
# 4     36       2      165.4       55.4        22.0         64       119
# ..   ...     ...        ...        ...         ...        ...       ...
# 414   42       1      172.2       70.9        20.5         81       142
# 415   24       1      172.0       70.6        14.7         62       112
# 416   33       1      186.8      117.5        28.3         78       133
# 417   34       1      170.6       71.7         9.7         69       115
# 418   24       2      168.2       54.0        15.9         66       102
#
#      gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm
# ...

# %%
y=df['class']
y
# Out:
# 0      A
# 1      C
# 2      B
# 3      B
# 4      B
#       ..
# 414    B
# 415    C
# 416    D
# 417    A
# 418    B
# Name: class, Length: 419, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,prediction)
score
# Out:
# 0.38095238095238093
